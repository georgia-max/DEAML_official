# %%
from data_preparation import *
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
sns.boxplot(x=ready_dataset['z1_TRAF_COMP'])
plt.show()
sns.boxplot(x=ready_dataset['z2_TRAF_DENS'])
plt.show()
sns.boxplot(x=ready_dataset['z3_RISK_INDEX'])
plt.show()
sns.boxplot(x=ready_dataset['z4_DELAY'])
plt.show()

# %%
print(X[:,2])
sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

sns.boxplot(x=ready_dataset['z1_TRAF_COMP'], color="m", ax=axes[0,0])
sns.boxplot(x=ready_dataset['z2_TRAF_DENS'], color="m", ax=axes[0, 1])
sns.boxplot(x=ready_dataset['z3_RISK_INDEX'], color="m", ax=axes[1, 0])
sns.boxplot(x=ready_dataset['z4_DELAY'], color="m", ax=axes[1, 1])
plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
#risk index
plt.figure(figsize = (12, 8))
sns.distplot(a= ready_dataset['z1_TRAF_COMP'])
plt.show()
sns.distplot(a= ready_dataset['z2_TRAF_DENS'])
plt.show()
sns.distplot(a= ready_dataset['z3_RISK_INDEX'])
plt.show()
sns.distplot(a= ready_dataset['z4_DELAY'])
plt.show()

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

sns.distplot(a= ready_dataset['z1_TRAF_COMP'], color="m", ax=axes[1, 1])
sns.distplot(a= ready_dataset['z2_TRAF_DENS'], color="m", ax=axes[0, 1])
sns.distplot(a= ready_dataset['z3_RISK_INDEX'], color="m", ax=axes[0, 0])
sns.distplot(a= ready_dataset['z4_DELAY'], color="m", ax=axes[1, 0])
plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
#TODO data visualization
#look at the distribution of effscore
sns.distplot(y,fit=norm)
plt.title('original Effscore distribution')
plt.xlabel('Eff score')
plt.ylabel('density')
fig = plt.figure()

# %%
corr_matrix=  ready_dataset.corr()
print(corr_matrix)
corr_matrix["Eff_scores"].sort_values(ascending=False)
#low correlation between predictor variables and tarrget variables. (Good)
